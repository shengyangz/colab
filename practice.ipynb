# %% [markdown]
# <a href="https://colab.research.google.com/github/shengyangz/colab/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd my
# Out:
# /content/my

# %%
from transformers import AutoModelForSequenceClassification,AutoTokenizer,pipeline
import pandas as pd
model = AutoModelForSequenceClassification.from_pretrained('uer/roberta-base-finetuned-chinanews-chinese')
tokenizer = AutoTokenizer.from_pretrained('uer/roberta-base-finetuned-chinanews-chinese')
text_classification = pipeline('sentiment-analysis', model=model, tokenizer=tokenizer)
text_classification("北京上个月召开了两会")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/880 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/409M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/295 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/110k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# [{'label': 'mainland China politics', 'score': 0.7211664319038391}]

# %%
import openpyxl

# 打开工作簿
workbook = openpyxl.load_workbook('pro2.xlsx')

# 选择工作表（默认选择第一个工作表）
sheet = workbook['Sheet1']  # 或者你也可以通过名字来选择：sheet = workbook['Sheet1']
# 读取一整列的值（例如，A列的值）
data = [cell.value for cell in sheet['A']]
print(data)

# 完成后关闭工作簿（虽然这通常不是必需的，因为Python的垃圾回收机制会自动处理）
workbook.close()
# Out:
# ['反映内容', '用户反映此处未知原因停水，已检查表前阀门属打开状态，请我司工作人员核实并立即处理。', '私自泄露诉求人信息的，视情节严重程度给予责任追究，请注意保密。如不属我司范围必须在一个工作日内回复结果并注明处理单位，否则将由我司处理。属我司范围，请处理后与用户联系解释好，上传与用户的通讯记录、处理现场的图片等材料作为差评申诉之用。详细填写结果以便回复政府平台。转民生诉求平台投诉：【供水问题】事发时间：2023年12月17日；事发地址：南山区粤海街道后海漾日湾畔；涉及范围：整个小区；是否向供水部门反映：水务公司临时通知停水；具体情况描述：市民来电反映该小区这段时间已经停水4次，说是因为建筑施工的问题，要求相关部门尽快处理该问题。具体诉求：要求相关部门尽快处理停水的问题。市民要求回复方式：短信或电话回复；工单编号 082401012220149153401（用户上报时间 2024-01-01 22:27:46）', '用户反映未知原因停水，已检查表前阀门属打开状态，请立即处理。', '用户反映未知原因停水，已检查表前阀门属打开状态，请尽快联系用户处理。（用户未提供联系人姓名信息）', '私自泄露诉求人信息的，视情节严重程度给予责任追究，请注意保密。（用户未留下联系方式，不需联系用户，客户联络中心将以文字和图片形式回复平台。如不属我司范围必须在一个工作日内回复结果并注明处理单位，否则将由我司处理。属我司范围保留处理现场的图片等材料作为差评申诉之用。）转民生诉求平台投诉：【行政效能投诉】投诉单位名称：深圳市水务集团；单位地址：深圳市；涉嫌违规人员姓名：；具体情况描述：漾日湾畔7栋资产被水务集团更换了水管之后，时不时停水；具体诉求：现来电投诉水务集团服务质量差；市民要求回复方式：其他方式回复；工单编号 082401012312247738301', '用户反映未知原因停水10天，已检查表前阀门属打开状态，请立即处理。', '用户反映未知原因停水，已检查表前阀门属打开状态，请立即处理。', '私自泄露诉求人信息的，视情节严重程度给予责任追究，请注意保密。如不属我司范围必须在一个工作日内回复结果并注明处理单位，否则将由我司处理。属我司范围，请处理后与用户联系解释好，上传与用户的通讯记录、处理现场的图片等材料作为差评申诉之用。详细填写结果以便回复政府平台。转民生诉求
# ...

# %%
for name in data:
    print(name)
    print(text_classification(name))
# Out:
# 反映内容
# [{'label': 'mainland China politics', 'score': 0.41574737429618835}]
# 用户反映此处未知原因停水，已检查表前阀门属打开状态，请我司工作人员核实并立即处理。
# [{'label': 'mainland China politics', 'score': 0.6082704067230225}]
# 私自泄露诉求人信息的，视情节严重程度给予责任追究，请注意保密。如不属我司范围必须在一个工作日内回复结果并注明处理单位，否则将由我司处理。属我司范围，请处理后与用户联系解释好，上传与用户的通讯记录、处理现场的图片等材料作为差评申诉之用。详细填写结果以便回复政府平台。转民生诉求平台投诉：【供水问题】事发时间：2023年12月17日；事发地址：南山区粤海街道后海漾日湾畔；涉及范围：整个小区；是否向供水部门反映：水务公司临时通知停水；具体情况描述：市民来电反映该小区这段时间已经停水4次，说是因为建筑施工的问题，要求相关部门尽快处理该问题。具体诉求：要求相关部门尽快处理停水的问题。市民要求回复方式：短信或电话回复；工单编号 082401012220149153401（用户上报时间 2024-01-01 22:27:46）
# [{'label': 'financial news', 'score': 0.8219356536865234}]
# 用户反映未知原因停水，已检查表前阀门属打开状态，请立即处理。
# [{'label': 'financial news', 'score': 0.7631784081459045}]
# 用户反映未知原因停水，已检查表前阀门属打开状态，请尽快联系用户处理。（用户未提供联系人姓名信息）
# [{'label': 'financial news', 'score': 0.8693385124206543}]
# ...
