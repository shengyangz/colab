# %% [markdown]
# <a href="https://colab.research.google.com/github/shengyangz/colab/blob/main/classification0618.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: read an excel file

import pandas as pd

# Read an Excel file
df = pd.read_excel('eee.xlsx')

# Print the DataFrame
print(df)
# Out:
#                     type                                               text  \
# 0           停水投诉=>未知原因停水          用户反映此处未知原因停水，已检查表前阀门属打开状态，请我司工作人员核实并立即处理。
# 1               停水投诉=>其它  私自泄露诉求人信息的，视情节严重程度给予责任追究，请注意保密。如不属我司范围必须在一个工作日...
# 2           停水投诉=>未知原因停水                     用户反映未知原因停水，已检查表前阀门属打开状态，请立即处理。
# 3           停水投诉=>未知原因停水   用户反映未知原因停水，已检查表前阀门属打开状态，请尽快联系用户处理。（用户未提供联系人姓名信息）
# 4         停水投诉=>同一片区多次停水  私自泄露诉求人信息的，视情节严重程度给予责任追究，请注意保密。（用户未留下联系方式，不需联系...
# ..                   ...                                                ...
# 514       停水投诉=>同一片区多次停水  用户反映小区水管改造后整栋楼经常出现停水，用户情绪很激动，并认为我司安排的施工方技术不合格，...
# 515  业务受理=>单位用户=>报停用水预受理  单位用户办理报停用水，请核实收取以下资料：经办人（周芳娟）身份证、《报停、恢复用水申请表》（...
# 516  业务受理=>单位用户=>报停用水预受理  单位用户办理报停用水，请核实收取以下资料：经办人（周芳娟）身份证、《报停、恢复用水申请表》（...
# 517  业务受理=>个人用户=>恢复用水预受理  个人用户办理恢复用水，请核实收取以下资料： 李先生的身份证（验原件收复印件）、用水地址的合法...
# 518        水压投诉=>长期水压不稳定  用户来电反映：1、长期水压不稳定，表示优饮施工改造后水压一直很低，无法正常生活；2、近两三年...
#
#     label
# 0       y
# 1       y
# 2       y
# ...

# %%
df.head()
# Out:
#              type                                               text label
# 0    停水投诉=>未知原因停水          用户反映此处未知原因停水，已检查表前阀门属打开状态，请我司工作人员核实并立即处理。     y
# 1        停水投诉=>其它  私自泄露诉求人信息的，视情节严重程度给予责任追究，请注意保密。如不属我司范围必须在一个工作日...     y
# 2    停水投诉=>未知原因停水                     用户反映未知原因停水，已检查表前阀门属打开状态，请立即处理。     y
# 3    停水投诉=>未知原因停水   用户反映未知原因停水，已检查表前阀门属打开状态，请尽快联系用户处理。（用户未提供联系人姓名信息）     y
# 4  停水投诉=>同一片区多次停水  私自泄露诉求人信息的，视情节严重程度给予责任追究，请注意保密。（用户未留下联系方式，不需联系...     y

# %%
df['label'] = df['label'].astype("category").cat.codes

# %%
df.head()
# Out:
#              type                                               text  label
# 0    停水投诉=>未知原因停水          用户反映此处未知原因停水，已检查表前阀门属打开状态，请我司工作人员核实并立即处理。      1
# 1        停水投诉=>其它  私自泄露诉求人信息的，视情节严重程度给予责任追究，请注意保密。如不属我司范围必须在一个工作日...      1
# 2    停水投诉=>未知原因停水                     用户反映未知原因停水，已检查表前阀门属打开状态，请立即处理。      1
# 3    停水投诉=>未知原因停水   用户反映未知原因停水，已检查表前阀门属打开状态，请尽快联系用户处理。（用户未提供联系人姓名信息）      1
# 4  停水投诉=>同一片区多次停水  私自泄露诉求人信息的，视情节严重程度给予责任追究，请注意保密。（用户未留下联系方式，不需联系...      1

# %% [markdown]
# 拆分训练集和测试集

# %%
from sklearn.model_selection import train_test_split
label = df.label
df.drop(columns='label', inplace=True)
# 测试集占比20%
df_train, df_test, y_train, y_test = train_test_split(df, label, test_size=0.2, stratify=label, random_state=42)
df_train['label'] = y_train

# %%
df_train.head()
# Out:
#                type                                               text  label
# 256   水压投诉=>长期水压不稳定                用户反映此处水压低，已持续三天以上，且出现间歇性停水情况，请立即处理。      1
# 460    停水投诉=>未知原因停水  用户反映该小区整栋未知原因停水，已检查表前阀门属打开状态，坐席未查询到有该小区应急抢修事件，...      1
# 214    停水投诉=>未知原因停水                     用户反映未知原因停水，已检查表前阀门属打开状态，请立即处理。      1
# 367  停水投诉=>同一片区多次停水  用户来电反映：该地近期多次停水，现在又没水了，情绪激动，对此非常生气，称严重影响正常生活，现...      1
# 32     停水投诉=>未知原因停水                     用户反映未知原因停水，已检查表前阀门属打开状态，请立即处理。      1

# %%
df_test.head()
# Out:
#                        type                                               text
# 372  停水投诉=>计划停水未提前通知（含延迟通水）  用户投诉朗麓家园计划停水未按时恢复供水，坐席已安抚解释道歉，因施工难度大，需延时至9时恢复供...
# 215            停水投诉=>未知原因停水  用户来电反映小区多户突然停水，已核实该处无相关停水事件及欠费停水，用户表示物业无法联系上，现...
# 162            停水投诉=>未知原因停水  用户反映整个小区未知原因停水，已检查表前阀门属打开状态，另外小区修水管的修几年了还没修好，搞...
# 463            停水投诉=>未知原因停水                     用户反映未知原因停水，已检查表前阀门属打开状态，请立即处理。
# 279  停水投诉=>计划停水未提前通知（含延迟通水）  用户了解到该小区8：30会开始停水，但是不到07:00就已经无水可用，用户对提前停水表示十分...

# %% [markdown]
# 拆分训练集和验证集

# %%
label = df_train.label
df_train.drop(columns='label', inplace=True)
# 验证集占5%
df_train, df_val, y_train, y_val = train_test_split(df_train, label, test_size=0.05, stratify=label, random_state=42)
df_train['label'] = y_train
df_val['label'] = y_val

# %%
df_train.head()
# Out:
#                        type  \
# 443  停水投诉=>计划停水未提前通知（含延迟通水）
# 384             查询/咨询=>其它咨询
# 259            停水投诉=>未知原因停水
# 53                 停水投诉=>其它
# 315             查询/咨询=>其它咨询
#
#                                                   text  label
# 443  用户来电咨询坪山区东纵路计划停水延时通水未及时通知，已向用户解释，要求跟进处理。（用户未提供...      1
# 384  私自泄露诉求人信息的，视情节严重程度给予责任追究，请注意保密。如不属我司范围必须在一个工作日...      1
# 259                     用户反映未知原因停水，已检查表前阀门属打开状态，请立即处理。      1
# 53   私自泄露诉求人信息的，视情节严重程度给予责任追究，请注意保密。如不属我司范围必须在一个工作日...      1
# 315  私自泄露诉求人信息的，视情节严重程度给予责任追究，请注意保密。（用户未留下联系方式，无需联系...      1

# %%
df_val.head()
# Out:
#                        type  \
# 453  停水投诉=>计划停水未提前通知（含延迟通水）
# 316             查询/咨询=>其它咨询
# 480             查询/咨询=>其它咨询
# 452  停水投诉=>计划停水未提前通知（含延迟通水）
# 454       查询/咨询=>收费信息=>水量异常
#
#                                                   text  label
# 453  用户来电投诉坪山区东纵路计划停水延时通水未及时通知，已向用户解释，要求跟进处理。（用户未提供姓氏）      1
# 316  私自泄露诉求人信息的，视情节严重程度给予责任追究，请注意保密。如不属我司范围必须在一个工作日...      1
# 480  私自泄露诉求人信息的，视情节严重程度给予责任追究，请注意保密。如不属我司范围必须在一个工作日...      1
# 452    用户投诉东纵路计划停水未按时恢复供水，已向用户解释，要求跟进处理。（用户未提供联系人姓名信息）      1
# 454  用户反映从2023年8月9日至2024年1月9日期间水量突增，已检查表后无漏水，且在此期间一...      1

# %% [markdown]
# 更改为transformer数据格式

# %%
from datasets import Dataset, DatasetDict
data = DatasetDict()
data['train'] = Dataset.from_pandas(df_train)
data['validation'] = Dataset.from_pandas(df_val)
data['test'] = Dataset.from_pandas(df_test)

# %%
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['type', 'text', 'label', '__index_level_0__'],
#         num_rows: 394
#     })
#     validation: Dataset({
#         features: ['type', 'text', 'label', '__index_level_0__'],
#         num_rows: 21
#     })
#     test: Dataset({
#         features: ['type', 'text', '__index_level_0__'],
#         num_rows: 104
#     })
# })

# %% [markdown]
# 对文本进行编码

# %%
from transformers import AutoTokenizer
model_pretrained = 'bert-base-chinese'
tokenizer = AutoTokenizer.from_pretrained(model_pretrained)
def tokenize(batch):
    return tokenizer(batch['text'], padding=True, truncation=True)

encoded = data.map(tokenize, batched=True, batch_size=None)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Map:   0%|          | 0/104 [00:00<?, ? examples/s]

# %%
encoded
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['type', 'text', 'label', '__index_level_0__', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 394
#     })
#     validation: Dataset({
#         features: ['type', 'text', 'label', '__index_level_0__', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 21
#     })
#     test: Dataset({
#         features: ['type', 'text', '__index_level_0__', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 104
#     })
# })

# %% [markdown]
# 预训练模型微调

# %%
# 调用GPU
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# 实例化模型
from transformers import AutoModelForSequenceClassification
# num_labels=2 表示将文本分为两类
model = AutoModelForSequenceClassification.from_pretrained(model_pretrained, num_labels=2).to(device)

# 设置训练参数
from transformers import TrainingArguments
batch_size = 5 # 16的时候崩溃了
logging_steps = len(encoded['train']) // batch_size
model_name = f"{model_pretrained}-finetuned-news"
training_args = TrainingArguments(
    report_to='none',
    output_dir=model_name,
    num_train_epochs=2, # 只训练两轮，耗时1.5小时
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    weight_decay=.01,
    evaluation_strategy='epoch',
    disable_tqdm=False,
    logging_steps=logging_steps,
    log_level='error',
)

# 模型训练和评估
from transformers import Trainer
from sklearn.metrics import accuracy_score, f1_score
def compute_metrics(pred):
    """Compute accuracy and f1 score
    """
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    f1 = f1_score(labels, preds, average='weighted')
    acc = accuracy_score(labels, preds)
    return {'accuracy': acc, 'f1': f1}
trainer = Trainer(
    model=model,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=encoded['train'],
    eval_dataset=encoded['validation'],
    tokenizer=tokenizer,
)
trainer.train()
trainer.save_model()
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-chinese and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1474: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='158' max='158' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [158/158 1:26:19, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
# ...

# %% [markdown]
# 在测试集进行模型评估

# %%
import numpy as np
label_test = trainer.predict(encoded['test'])
y_pre = np.argmax(label_test.predictions, axis=-1)

# %%
y_true = [i for i in y_test]

# %%
acc = accuracy_score(y_true, y_pre)

# %%
acc
# Out:
# 0.9711538461538461

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-base-chinese-finetuned-news",local_files_only=True)
model = AutoModelForSequenceClassification.from_pretrained("bert-base-chinese-finetuned-news",local_files_only=True, num_labels=2)

# %% [markdown]
# 使用模型进行实例验证

# %%
text = "水管爆了，水务集团的人来修一下。"
encoder = tokenizer(text, return_tensors="pt")

# %%
import torch
with torch.no_grad():
    logits = model(**encoder).logits

predicted_class_id = logits.argmax().item()

# %%
predicted_class_id
# Out:
# 1
